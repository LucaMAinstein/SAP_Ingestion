# %%
### Import of libs

from pyspark.sql.functions import current_date, current_timestamp, expr
# Out:
# StatementMeta(, fbf7d3b4-e17c-4a2e-af77-6e514c50991b, 46, Finished, Available, Finished)

# %%
# Function to add a comment on the table

def AddComentTable(a,b,c,d):
    spark.sql(f"COMMENT ON TABLE {a}.{b} IS 'C'")
    for key,value in d.items():
        sqlaux = f"ALTER TABLE {a}.{b} CHANGE COLUMN {key} COMMENT '{value}'"
        spark.sql(sqlaux)
# Out:
# StatementMeta(, fbf7d3b4-e17c-4a2e-af77-6e514c50991b, 47, Finished, Available, Finished)

# %%
# %%sql
# SELECT
#     Source_Name,
#     CAST(WBS AS string),
#     CAST(sap_internal_number AS string),
#     Project_BA,
#     load_time_GMT
# FROM delta.`Tables/Bronze/IO_Project/bronze_IO_Project`
# Out:
# StatementMeta(, fbf7d3b4-e17c-4a2e-af77-6e514c50991b, 48, Finished, Available, Finished)
# <Spark SQL result set with 12 rows and 5 fields>

# %%
## Silver Table creation - IO->Project

### Table Creation

df = spark.sql(
f"""
SELECT
    Source_Name,
    CAST(WBS AS string),
    CAST(sap_internal_number AS string),
    Project_BA,
    load_time_GMT
FROM delta.`Tables/Bronze/IO_Project/bronze_IO_Project` 
"""
)

df = df.withColumn("load_time_GMT", current_timestamp())

### Note that it is GMT. Please see Layer bronze for further details.

# Caminho do destino
caminho = "abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/IO_Project/silver_IO_Project"


# Salvando o DataFrame no formato Delta
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save(caminho)

print("Dados salvos com sucesso!")

# Executando o comando OPTIMIZE para otimizar a tabela Delta
spark.sql(f"OPTIMIZE delta.`{caminho}`")

# Confirmação de que a otimização foi concluída
print(f"Optimization for {caminho} completed!")
# Out:
# StatementMeta(, fbf7d3b4-e17c-4a2e-af77-6e514c50991b, 49, Finished, Available, Finished)
# Dados salvos com sucesso!
# Optimization for abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/IO_Project/silver_IO_Project completed!

# %%
## Silver Table creation - ZONE 1

### Table Creation

df = spark.sql(
f"""
SELECT
    CAST(Source_name AS string),
    CAST(WBS AS string),
    CAST(sap_internal_number AS string),
    CAST(SAP_source AS string),
    CAST(Currency AS string),
    CAST(Year AS string),
    CAST(BGT_LC AS string),
    CAST(ACT_LC AS string),
    CAST(COM_LC AS string),
    CAST(load_time_GMT AS string)
FROM delta.`Tables/Bronze/Zone1/bronze_zone1` 
"""
)

df = df.withColumn("load_time_GMT", current_timestamp())

### Note that it is GMT. Please see Layer bronze for further details.

# Caminho do destino
caminho = "abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/Zone1/silver_Zone1"


# Salvando o DataFrame no formato Delta
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save(caminho)

print("Dados salvos com sucesso!")

# Executando o comando OPTIMIZE para otimizar a tabela Delta
spark.sql(f"OPTIMIZE delta.`{caminho}`")

# Confirmação de que a otimização foi concluída
print(f"Optimization for {caminho} completed!")
# Out:
# StatementMeta(, fbf7d3b4-e17c-4a2e-af77-6e514c50991b, 50, Finished, Available, Finished)
# Dados salvos com sucesso!
# Optimization for abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/Zone1/silver_Zone1 completed!

# %%
## Silver Table creation - ZONE 2

### Table Creation

df = spark.sql(
f"""
SELECT
    CAST(Source_name AS string),
    CAST(WBS AS string),
    CAST(sap_internal_number AS string),
    CAST(SAP_source AS string),
    CAST(Currency AS string),
    CAST(Year AS string),
    CAST(BGT_LC AS string),
    CAST(ACT_LC AS string),
    CAST(COM_LC AS string),
    CAST(load_time_GMT AS string)
FROM delta.`Tables/Bronze/Zone2/bronze_zone2` 
"""
)

df = df.withColumn("load_time_GMT", current_timestamp())

### Note that it is GMT. Please see Layer bronze for further details.

# Caminho do destino
caminho = "abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/Zone2/silver_Zone2"


# Salvando o DataFrame no formato Delta
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save(caminho)

print("Dados salvos com sucesso!")

# Executando o comando OPTIMIZE para otimizar a tabela Delta
spark.sql(f"OPTIMIZE delta.`{caminho}`")

# Confirmação de que a otimização foi concluída
print(f"Optimization for {caminho} completed!")
# Out:
# StatementMeta(, fbf7d3b4-e17c-4a2e-af77-6e514c50991b, 51, Finished, Available, Finished)
# Dados salvos com sucesso!
# Optimization for abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/Zone2/silver_Zone2 completed!

# %%
## Silver Table creation - ZONE 3

### Table Creation

df = spark.sql(
f"""
SELECT
    CAST(Source_name AS string),
    CAST(WBS AS string),
    CAST(sap_internal_number AS string),
    CAST(SAP_source AS string),
    CAST(Currency AS string),
    CAST(Year AS string),
    CAST(BGT_LC AS string),
    CAST(ACT_LC AS string),
    CAST(COM_LC AS string),
    CAST(load_time_GMT AS string)
FROM delta.`Tables/Bronze/Zone3/bronze_zone3` 
"""
)

df = df.withColumn("load_time_GMT", current_timestamp())

### Note that it is GMT. Please see Layer bronze for further details.

# Caminho do destino
caminho = "abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/Zone3/silver_Zone3"


# Salvando o DataFrame no formato Delta
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save(caminho)

print("Dados salvos com sucesso!")

# Executando o comando OPTIMIZE para otimizar a tabela Delta
spark.sql(f"OPTIMIZE delta.`{caminho}`")

# Confirmação de que a otimização foi concluída
print(f"Optimization for {caminho} completed!")
# Out:
# StatementMeta(, fbf7d3b4-e17c-4a2e-af77-6e514c50991b, 52, Finished, Available, Finished)
# Dados salvos com sucesso!
# Optimization for abfss://SAP_Ingest_v2@onelake.dfs.fabric.microsoft.com/Silver.Lakehouse/Tables/dbo/Silver/Zone3/silver_Zone3 completed!
